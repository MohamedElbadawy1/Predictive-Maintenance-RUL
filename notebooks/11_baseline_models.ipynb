# %% [markdown]
# ## Random Forest Baseline
#
# This notebook trains the first traditional machine learning baseline model using the prepared NASA RUL dataset.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent

sys.path.append(str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# A:\AI_Engineer\ML Projects\Predictive-Maintenance-RUL

# %%
import pandas as pd

from src.data.loader import DataLoader
from src.data.validator import DataValidator
from src.preprocessing.rul_generator import RULGenerator
from src.preprocessing.feature_engineer import FeatureEngineer

from src.preprocessing.feature_selector import FeatureSelector
from src.preprocessing.data_splitter import DataSplitter
from src.preprocessing.feature_scaler import FeatureScaler
from src.preprocessing.preparation_pipeline import DataPreparationPipeline
from src.evaluation.evaluator import RegressionEvaluator
from src.utils.constant import SENSOR_COLUMNS

from src.config.config import (
    TRAIN_DATA_PATH,
    TEST_DATA_PATH,
    RUL_DATA_PATH
)

# %% [markdown]
# 1- LOAD DATA

# %%
loader = DataLoader(
    train_path=TRAIN_DATA_PATH,
    test_path=TEST_DATA_PATH,
    rul_path=RUL_DATA_PATH,
)

train_df = loader.load_train()
test_df = loader.load_test()
rul_df = loader.load_rul()
# Out:
# 2026-08-22 12:28:47 | INFO | loader.py | Line:18 | Reading train_FD004.txt
# 2026-08-22 12:28:49 | INFO | loader.py | Line:21 | train_FD004.txt Loaded Successfully
# 2026-08-22 12:28:49 | INFO | loader.py | Line:18 | Reading test_FD004.txt
# 2026-08-22 12:28:50 | INFO | loader.py | Line:21 | test_FD004.txt Loaded Successfully
# 2026-08-22 12:28:50 | INFO | loader.py | Line:18 | Reading RUL_FD004.txt
# 2026-08-22 12:28:50 | INFO | loader.py | Line:21 | RUL_FD004.txt Loaded Successfully

# %% [markdown]
# 2- VALIDATE DATA

# %%
validator = DataValidator(
    train_df,
    test_df,
    rul_df
)

validator.validate_all()
# Out:
# 2026-08-22 12:28:50 | INFO | validator.py | Line:40 | Validating training dataset...
# 2026-08-22 12:28:50 | INFO | validator.py | Line:50 | Validating testing dataset...
# 2026-08-22 12:28:50 | INFO | validator.py | Line:60 | Validating RUL dataset...
# {'train': {'valid': True, 'errors': [], 'warnings': []},
#  'test': {'valid': True, 'errors': [], 'warnings': []},
#  'rul': {'valid': True, 'errors': [], 'warnings': ['Duplicate rows found.']}}

# %% [markdown]
# 3- Generate RUL

# %%
generator = RULGenerator(train_df=train_df)

train_df = generator.generate(cap=130)

train_df.head()
# Out:
# 2026-08-22 12:28:50 | INFO | rul_generator.py | Line:82 | Generating Remaining Useful Life (RUL)...
# 2026-08-22 12:28:50 | INFO | rul_generator.py | Line:92 | Applying RUL cap = 130
# 2026-08-22 12:28:50 | INFO | rul_generator.py | Line:96 | RUL generated successfully.
#    unit_number  time_in_cycles  operational_setting_1  operational_setting_2  \
# 0            1               1                42.0049                 0.8400
# 1            1               2                20.0020                 0.7002
# 2            1               3                42.0038                 0.8409
# 3            1               4                42.0000                 0.8400
# 4            1               5                25.0063                 0.6207
#
#    operational_setting_3  sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 0                  100.0    445.00    549.68   1343.43   1112.93      3.91
# 1                  100.0    491.19    606.07   1477.61   1237.50      9.35
# 2                  100.0    445.00    548.95   1343.12   1117.05      3.91
# 3                  100.0    445.00    548.70   1341.24   1118.03      3.91
# 4                   60.0    462.54    536.10   1255.23   1033.59      7.05
#
#    ...  sensor_13  sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  \
# 0  ...    2387.99    8074.83     9.3335       0.02        330       2212
# 1  ...    2387.73    8046.13     9.1913       0.02        361       2324
# 2  ...    2387.97    8066.62     9.4007       0.02        329       2212
# 3  ...    2388.02    8076.05     9.3369       0.02        328       2212
# 4  ...    2028.08    7865.80    10.8366       0.02        305       1915
#
#    sensor_19  sensor_20  sensor_21  RUL
# 0     100.00      10.62     6.3670  130
# 1     100.00      24.37    14.6552  130
# 2     100.00      10.48     6.4213  130
# 3     100.00      10.54     6.4176  130
# 4      84.93      14.03     8.6754  130
#
# [5 rows x 27 columns]

# %% [markdown]
# 4- Feature Engineering

# %%
engineer = FeatureEngineer(sensor_columns=SENSOR_COLUMNS,lags=[1,2,3],)

feature_df = engineer.transform(train_df)
feature_df.head()
# Out:
# 2026-08-22 12:28:51 | INFO | feature_engineer.py | Line:50 | Starting Feature Engineering...
# 2026-08-22 12:28:51 | INFO | feature_engineer.py | Line:119 | Generating Rolling Mean features...
# 2026-08-22 12:28:52 | INFO | feature_engineer.py | Line:148 | Generating Rolling Std features...
# 2026-08-22 12:28:54 | INFO | feature_engineer.py | Line:179 | Generating Lag Features...
# A:\AI_Engineer\ML Projects\Predictive-Maintenance-RUL\src\preprocessing\feature_engineer.py:189: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[feature_name] = (
# 2026-08-22 12:28:54 | INFO | feature_engineer.py | Line:205 | Generating Rate of Change features...
# A:\AI_Engineer\ML Projects\Predictive-Maintenance-RUL\src\preprocessing\feature_engineer.py:213: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[feature_name] = (
# 2026-08-22 12:28:54 | INFO | feature_engineer.py | Line:61 | Feature Engineering completed successfully.
#    unit_number  time_in_cycles  operational_setting_1  operational_setting_2  \
# 0            1               1                42.0049                 0.8400
# 1            1               2                20.0020                 0.7002
# 2            1               3                42.0038                 0.8409
# 3            1               4                42.0000                 0.8400
# 4            1               5                25.0063                 0.6207
#
#    operational_setting_3  sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 0                  100.0    445.00    549.68   1343.43   1112.93      3.91
# 1                  100.0    491.19    606.07   1477.61   1237.50      9.35
# 2                  100.0    445.00    548.95   1343.12   1117.05      3.91
# 3                  100.0    445.00    548.70   1341.24   1118.03      3.91
# 4                   60.0    462.54    536.10   1255.23   1033.59      7.05
#
#    ...  sensor_12_diff  sensor_13_diff  sensor_14_diff  sensor_15_diff  \
# 0  ...             NaN             NaN             NaN             NaN
# 1  ...          182.81           -0.26          -28.70         -0.1422
# 2  ...         -182.97            0.24           20.49          0.2094
# 3  ...            0.18            0.05            9.43         -0.0638
# 4  ...           34.31         -359.94         -210.25          1.4997
#
#    sensor_16_diff  sensor_17_diff  sensor_18_diff  sensor_19_diff  \
# 0             NaN             NaN             NaN             NaN
# 1             0.0            31.0           112.0            0.00
# 2             0.0           -32.0          -112.0            0.00
# 3             0.0            -1.0             0.0            0.00
# 4             0.0           -23.0          -297.0          -15.07
#
#    sensor_20_diff  sensor_21_diff
# 0             NaN             NaN
# 1           13.75          8.2882
# 2          -13.89         -8.2339
# 3            0.06         -0.0037
# 4            3.49          2.2578
#
# [5 rows x 153 columns]

# %% [markdown]
# 5- Create Pipeline

# %%
pipeline = DataPreparationPipeline(

    splitter=DataSplitter(
        test_size=0.2,
    ),

    selector=FeatureSelector(

        target_column="RUL",

        drop_columns=[
            "unit_number",
        ],

    ),

    scaler=FeatureScaler(),

)

# %%
X_train, X_val, y_train, y_val = pipeline.prepare(
    feature_df
)
# Out:
# 2026-08-22 12:28:54 | INFO | preparation_pipeline.py | Line:37 | Starting Data Preparation Pipeline...
# 2026-08-22 12:28:54 | INFO | data_splitter.py | Line:35 | Starting engine-based train/validation split...
# 2026-08-22 12:28:54 | INFO | data_splitter.py | Line:67 | Train Engines: 199 | Validation Engines: 50
# 2026-08-22 12:28:54 | INFO | data_splitter.py | Line:72 | Data splitting completed successfully.
# 2026-08-22 12:28:54 | INFO | feature_selector.py | Line:29 | Starting Feature Selection...
# 2026-08-22 12:28:54 | INFO | feature_selector.py | Line:40 | Feature Selection completed successfully.
# 2026-08-22 12:28:54 | INFO | feature_selector.py | Line:29 | Starting Feature Selection...
# 2026-08-22 12:28:54 | INFO | feature_selector.py | Line:40 | Feature Selection completed successfully.
# 2026-08-22 12:28:54 | INFO | feature_scaler.py | Line:33 | Fitting Feature Scaler...
# 2026-08-22 12:28:55 | INFO | feature_scaler.py | Line:37 | Feature Scaler fitted successfully.
# 2026-08-22 12:28:55 | INFO | feature_scaler.py | Line:44 | Transforming features...
# 2026-08-22 12:28:55 | INFO | feature_scaler.py | Line:60 | Feature transformation completed.
# 2026-08-22 12:28:55 | INFO | feature_scaler.py | Line:44 | Transforming features...
# 2026-08-22 12:28:55 | INFO | feature_scaler.py | Line:60 | Feature transformation completed.
# 2026-08-22 12:28:55 | INFO | preparation_pipeline.py | Line:45 | Data Preparation completed successfully.

# %%
print("Training Features :", X_train.shape)
print("Validation Features :", X_val.shape,"\n")

print("Training Target :", y_train.shape)
print("Validation Target :", y_val.shape)
# Out:
# Training Features : (49294, 151)
# Validation Features : (11955, 151)
#
# Training Target : (49294,)
# Validation Target : (11955,)

# %%
from src.models.traditional_ml_benchmark import TraditionalMLBenchmark

benchmark = TraditionalMLBenchmark()

results, best_trainer = benchmark.run(
    X_train,
    y_train,
    X_val,
    y_val,
)

results
# Out:
# 2026-08-22 12:28:55 | INFO | traditional_ml_benchmark.py | Line:35 | Starting Traditional ML Benchmark...
# 2026-08-22 12:28:55 | INFO | traditional_ml_benchmark.py | Line:44 | Training random_forest...
# 2026-08-22 12:28:55 | INFO | base_trainer.py | Line:24 | Training RandomForestRegressor...
# 2026-08-22 12:33:20 | INFO | base_trainer.py | Line:30 | Training completed successfully.
# 2026-08-22 12:33:20 | INFO | base_trainer.py | Line:37 | Generating predictions using RandomForestRegressor...
# 2026-08-22 12:33:21 | INFO | evaluator.py | Line:47 | Starting regression evaluation...
# 2026-08-22 12:33:21 | INFO | evaluator.py | Line:80 | Evaluation completed successfully.
# 2026-08-22 12:33:21 | INFO | traditional_ml_benchmark.py | Line:67 | random_forest | RMSE=21.0999 | R2=0.7567
# 2026-08-22 12:33:21 | INFO | traditional_ml_benchmark.py | Line:44 | Training xgboost...
# 2026-08-22 12:33:21 | INFO | base_trainer.py | Line:24 | Training XGBRegressor...
# 2026-08-22 12:33:30 | INFO | base_trainer.py | Line:30 | Training completed successfully.
# 2026-08-22 12:33:30 | INFO | base_trainer.py | Line:37 | Generating predictions using XGBRegressor...
# 2026-08-22 12:33:30 | INFO | evaluator.py | Line:47 | Starting regression evaluation...
# 2026-08-22 12:33:30 | INFO | evaluator.py | Line:80 | Evaluation completed successfully.
# 2026-08-22 12:33:30 | INFO | traditional_ml_benchmark.py | Line:67 | xgboost | RMSE=21.0453 | R2=0.7580
# 2026-08-22 12:33:30 | INFO | traditional_ml_benchmark.py | Line:44 | Training lightgbm...
# 2026-08-22 12:33:30 | INFO | base_trainer.py | Line:24 | Training LGBMRegressor...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.064696 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 27946
# [LightGBM] [Info] Number of data points in the train set: 49294, number of used features: 151
# [LightGBM] [Info] Start training from score 95.624985
# 2026-08-22 12:33:35 | INFO | base_trainer.py | Line:30 | Training completed successfully.
# 2026-08-22 12:33:35 | INFO | base_trainer.py | Line:37 | Generating predictions using LGBMRegressor...
# 2026-08-22 12:33:35 | INFO | evaluator.py | Line:47 | Starting regression evaluation...
# 2026-08-22 12:33:35 | INFO | evaluator.py | Line:80 | Evaluation completed successfully.
# 2026-08-22 12:33:35 | INFO | traditional_ml_benchmark.py | Line:67 | lightgbm | RMSE=20.9778 | R2=0.7595
# 2026-08-22 12:33:35 | INFO | traditional_ml_benchmark.py | Line:44 | Training catboost...
# 2026-08-22 12:33:35 | INFO | base_trainer.py | Line:24 | Training CatBoostRegressor...
# 2026-08-22 12:34:19 | INFO | base_trainer.py | Line:30 | Training completed successfully.
# 2026-08-22 12:34:19 | INFO | base_trainer.py | Line:37 | Generating predictions using CatBoostRegressor...
# 2026-08-22 12:34:19 | INFO | evaluator.py | Line:47 | Starting regression evaluation...
# 2026-08-22 12:34:19 | INFO | evaluator.py | Line:80 | Evaluation completed successfully.
# 2026-08-22 12:34:19 | INFO | traditional_ml_benchmark.py | Line:67 | catboost | RMSE=20.2873 | R2=0.7751
# 2026-08-22 12:34:19 | INFO | traditional_ml_benchmark.py | Line:86 | Benchmark completed successfully.
#          MAE       RMSE        R2       MAPE          Model  Training Time
# 0  13.872356  20.287256  0.775102  25.821728       catboost      44.491492
# 1  14.208113  20.977765  0.759532  27.264849       lightgbm       4.727170
# 2  14.440435  21.045281  0.757981  28.055535        xgboost       9.081667
# 3  14.450108  21.099885  0.756724  29.315692  random_forest     265.343900

# %%
from src.experiments.experiment_tracker import ExperimentTracker

tracker = ExperimentTracker()

tracker.save_results(results)

tracker.save_best_model(
    trainer=best_trainer,
    model_name=results.iloc[0]["Model"],
)

tracker.save_feature_importance(
    trainer=best_trainer,
    feature_names=X_train.columns,
)

tracker.save_summary(
    {
        "Best Model": results.iloc[0]["Model"],
        "MAE": float(results.iloc[0]["MAE"]),
        "RMSE": float(results.iloc[0]["RMSE"]),
        "R2": float(results.iloc[0]["R2"]),
        "MAPE": float(results.iloc[0]["MAPE"]),
        "Training Time": float(results.iloc[0]["Training Time"]),
    }
)
# Out:
# 2026-08-22 12:34:19 | INFO | experiment_tracker.py | Line:48 | Experiment directory created at A:\AI_Engineer\ML Projects\Predictive-Maintenance-RUL\artifacts\experiments\2026-08-22_12-34-19
# 2026-08-22 12:34:19 | INFO | experiment_tracker.py | Line:67 | Benchmark results saved.
# 2026-08-22 12:34:20 | INFO | base_trainer.py | Line:59 | Model saved to A:\AI_Engineer\ML Projects\Predictive-Maintenance-RUL\artifacts\experiments\2026-08-22_12-34-19\best_model.pkl
# 2026-08-22 12:34:20 | INFO | experiment_tracker.py | Line:124 | Best model saved.
# 2026-08-22 12:34:20 | INFO | experiment_tracker.py | Line:168 | Feature importance saved.
# 2026-08-22 12:34:20 | INFO | experiment_tracker.py | Line:189 | Summary saved.

# %%
from src.explainability.feature_importance import FeatureImportanceAnalyzer

analyzer = FeatureImportanceAnalyzer()

importance_df = analyzer.get_importance(
    model=best_trainer.model,
    feature_names=X_train.columns,
)

importance_df.head(20)
# Out:
# 2026-08-22 12:34:20 | INFO | feature_importance.py | Line:16 | Computing feature importance...
# 2026-08-22 12:34:20 | INFO | feature_importance.py | Line:40 | Feature importance computed successfully.
#             feature  importance
# 0    time_in_cycles   17.527875
# 1         sensor_13    7.308094
# 2   sensor_13_lag_1    6.313742
# 3   sensor_13_lag_2    5.696451
# 4   sensor_13_lag_3    5.313667
# 5         sensor_15    4.811833
# 6   sensor_11_lag_3    4.184689
# 7   sensor_15_lag_1    3.606991
# 8   sensor_11_lag_2    3.369284
# 9   sensor_15_lag_2    3.061067
# 10  sensor_11_lag_1    3.021675
# 11        sensor_11    2.989740
# 12  sensor_15_lag_3    2.830711
# 13   sensor_6_lag_3    2.697392
# 14   sensor_4_lag_1    2.670308
# 15   sensor_6_lag_2    2.489833
# 16         sensor_4    2.261791
# 17   sensor_6_lag_1    2.216641
# 18   sensor_4_lag_2    2.096637
# 19         sensor_6    1.664407

# %%
top10 = analyzer.get_top_features(
    importance_df,
    top_n=10,
)

top10
# Out:
#            feature  importance
# 0   time_in_cycles   17.527875
# 1        sensor_13    7.308094
# 2  sensor_13_lag_1    6.313742
# 3  sensor_13_lag_2    5.696451
# 4  sensor_13_lag_3    5.313667
# 5        sensor_15    4.811833
# 6  sensor_11_lag_3    4.184689
# 7  sensor_15_lag_1    3.606991
# 8  sensor_11_lag_2    3.369284
# 9  sensor_15_lag_2    3.061067

# %%
zero_features = analyzer.get_zero_importance(
    importance_df,
)

print(len(zero_features))

zero_features.head()
# Out:
# 23
#                    feature  importance
# 128              sensor_19         0.0
# 129               sensor_5         0.0
# 130  operational_setting_3         0.0
# 131               sensor_1         0.0
# 132              sensor_18         0.0
